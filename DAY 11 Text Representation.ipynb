# %%
import numpy as np
import pandas as pd

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in d:\anaconda\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in d:\anaconda\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in d:\anaconda\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in d:\anaconda\lib\site-packages (from gensim) (5.2.1)

# %%
import gensim
import os

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Prabhsimrat
# [nltk_data]     Singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Prabhsimrat
# [nltk_data]     Singh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from charset_normalizer import from_path

result = from_path(file_path).best()
print(result.encoding)
# Out:
# cp1250

# %%
import os
import kagglehub
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# Download (or use cached copy)
path = kagglehub.dataset_download("khulasasndh/game-of-thrones-books")

story = []

for filename in os.listdir(path):
    file_path = os.path.join(path, filename)

    if os.path.isfile(file_path):
        with open(file_path, "r", encoding="cp1250") as f:
            corpus = f.read()

        raw_sent = sent_tokenize(corpus)

        for sent in raw_sent:
            story.append(simple_preprocess(sent))

print(len(story))
# Out:
# 145020

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (6569607, 8628190)

# %%
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.8194804191589355),
#  ('targaryen', 0.7422781586647034),
#  ('unburnt', 0.7253304719924927),
#  ('queen', 0.6965262293815613),
#  ('elia', 0.6943457722663879),
#  ('myrcella', 0.691140353679657),
#  ('viserys', 0.6874501705169678),
#  ('princess', 0.6781860589981079),
#  ('dorne', 0.6694868206977844),
#  ('margaery', 0.6412304043769836)]

# %%
model.wv.doesnt_match(['cersei', 'jaime', 'bronn', 'tyrion'])
# Out:
# 'bronn'
